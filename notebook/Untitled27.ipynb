# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from zipfile import ZipFile

# Specify the path to your zip file
zip_path = "/content/drive/MyDrive/ml/Aquarium Combined.v2-raw-1024.yolov11.zip"


# Unzip the contents to a specified directory
with ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall('/content/My folder_extracted')

print("Unzipping complete!")
# Out:
# Unzipping complete!

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.9/906.9 kB 18.1 MB/s eta 0:00:00
# ...

# %%
import torch
from ultralytics import YOLO

model=YOLO("/content/yolo11n.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 163MB/s]

# %%
devicee = "cuda" if torch.cuda.is_available() else "cpu"
print(devicee)
# Out:
# cuda

# %%
model.train(data = "/content/My folder_extracted/data.yaml", imgsz = 640 , batch = 40,
             epochs = 50, device = devicee)
# Out:
# Ultralytics 8.3.61 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model.train(data = "/content/My folder_extracted/data.yaml", imgsz = 640 , batch = 40,
             epochs = 200, device = devicee)
# Out:
# Ultralytics 8.3.61 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO("/content/runs/detect/train/weights/best.pt")

# Perform prediction
results = model.predict(source="/content/IMG_8497_MOV-3_jpg.rf.fd813e14681c8b41e709a500748ce46a.jpg", show=True, save=True, conf=0.4)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /content/IMG_8497_MOV-3_jpg.rf.fd813e14681c8b41e709a500748ce46a.jpg: 640x384 5 fishs, 17.4ms
# Speed: 2.8ms preprocess, 17.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict2

# %%
model = YOLO("/content/runs/detect/train/weights/best.pt")

# Perform prediction
results = model.predict(source="/content/IMG_8515_jpg.rf.98a9daca7c5a5bad9872bd7fb2d4f198.jpg", show=True, save=True, conf=0.4)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /content/IMG_8515_jpg.rf.98a9daca7c5a5bad9872bd7fb2d4f198.jpg: 480x640 5 fishs, 48.1ms
# Speed: 3.0ms preprocess, 48.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict3

# %%
model = YOLO("/content/runs/detect/train/weights/best.pt")

# Perform prediction
results = model.predict(source="/content/IMG_8404_jpg.rf.265b89e862a375f6b89f781ea60ed480.jpg", show=True, save=True, conf=0.4)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /content/IMG_8404_jpg.rf.265b89e862a375f6b89f781ea60ed480.jpg: 480x640 10 fishs, 1 stingray, 12.2ms
# Speed: 3.0ms preprocess, 12.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict4

# %%
model = YOLO("/content/runs/detect/train/weights/best.pt")

# Perform prediction
results = model.predict(source="/content/IMG_2380_jpeg_jpg.rf.a23809682eb1466c1136ca0f55de8fb5.jpg", show=True, save=True, conf=0.4)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /content/IMG_2380_jpeg_jpg.rf.a23809682eb1466c1136ca0f55de8fb5.jpg: 640x480 1 fish, 45.1ms
# Speed: 2.8ms preprocess, 45.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict5

# %%
model = YOLO("/content/runs/detect/train/weights/best.pt")

# Perform prediction
results = model.predict(source="/content/IMG_2514_jpeg_jpg.rf.6ccb3859d75fc5cfe053b1c1474254b2.jpg", show=True, save=True, conf=0.4)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /content/IMG_2514_jpeg_jpg.rf.6ccb3859d75fc5cfe053b1c1474254b2.jpg: 640x480 2 sharks, 11.5ms
# Speed: 2.7ms preprocess, 11.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict6

# %%
model = YOLO("/content/runs/detect/train/weights/best.pt")

# Perform prediction
results = model.predict(source="/content/IMG_2387_jpeg_jpg.rf.09b38bacfab0922a3a6b66480f01b719.jpg", show=True, save=True, conf=0.4)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /content/IMG_2387_jpeg_jpg.rf.09b38bacfab0922a3a6b66480f01b719.jpg: 640x480 1 starfish, 12.0ms
# Speed: 3.4ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict7
